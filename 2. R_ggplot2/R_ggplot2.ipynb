# %%
hist(iris$Sepal.Length,col="blue")
# Out:
# Plot with title "Histogram of iris$Sepal.Length"

# %%
barplot(iris$Sepal.Length)
# Out:
# plot without title

# %%
table(iris$Sepal.Length)
# Out:
# 4.3 4.4 4.5 4.6 4.7 4.8 4.9   5 5.1 5.2 5.3 5.4 5.5 5.6 5.7 5.8 5.9   6 6.1 6.2
#   1   3   1   4   2   5   6  10   9   4   1   6   7   6   8   7   3   6   6   4
# 6.3 6.4 6.5 6.6 6.7 6.8 6.9   7 7.1 7.2 7.3 7.4 7.6 7.7 7.9
#   9   7   5   2   8   3   4   1   1   3   1   1   1   4   1

# %%
t<-table(iris$Sepal.Length)
addmargins(t)
# Out:
# 4.3 4.4 4.5 4.6 4.7 4.8 4.9   5 5.1 5.2 5.3 5.4 5.5 5.6 5.7 5.8 5.9   6 6.1 6.2
#   1   3   1   4   2   5   6  10   9   4   1   6   7   6   8   7   3   6   6   4
# 6.3 6.4 6.5 6.6 6.7 6.8 6.9   7 7.1 7.2 7.3 7.4 7.6 7.7 7.9 Sum
#   9   7   5   2   8   3   4   1   1   3   1   1   1   4   1 150

# %%
barplot(table(t), xlab="t", ylab="frequency")
# Out:
# plot without title

# %%
boxplot(Sepal.Width ~ Species, data=iris, xlab="Species",ylab="Sepal.Width")
# Out:
# plot without title

# %%
plot(iris$Sepal.Length,iris$Petal.Length, main="scatterplot example", col="blue")
# Out:
# Plot with title "scatterplot example"

# %%
pairs(iris[,1:4])
# Out:
# plot without title

# %%
iris$Species
# Out:
#   [1] setosa     setosa     setosa     setosa     setosa     setosa
#   [7] setosa     setosa     setosa     setosa     setosa     setosa
#  [13] setosa     setosa     setosa     setosa     setosa     setosa
#  [19] setosa     setosa     setosa     setosa     setosa     setosa
#  [25] setosa     setosa     setosa     setosa     setosa     setosa
#  [31] setosa     setosa     setosa     setosa     setosa     setosa
#  [37] setosa     setosa     setosa     setosa     setosa     setosa
#  [43] setosa     setosa     setosa     setosa     setosa     setosa
#  [49] setosa     setosa     versicolor versicolor versicolor versicolor
#  [55] versicolor versicolor versicolor versicolor versicolor versicolor
#  [61] versicolor versicolor versicolor versicolor versicolor versicolor
#  [67] versicolor versicolor versicolor versicolor versicolor versicolor
#  [73] versicolor versicolor versicolor versicolor versicolor versicolor
# ...

# %%
table(iris$Species)
# Out:
#     setosa versicolor  virginica
#         50         50         50

# %%
pie(table(iris$Species)/length(iris$Species), labels=c("1:setosa","2:versicolor","3:virginica"))
# Out:
# plot without title

# %%
install.packages("ggplot2", repos = "http://cran.us.r-project.org")
library(ggplot2)
install.packages("gcookbook", repos = "http://cran.us.r-project.org")
library(gcookbook)
# Out:
# Warning message:
# "package 'ggplot2' is in use and will not be installed"
# package 'gcookbook' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\kellyzhai\AppData\Local\Temp\RtmpolD6QP\downloaded_packages
# Warning message:
# "package 'gcookbook' was built under R version 3.3.3"

# %%
dim(iris)
# Out:
# [1] 150   5

# %%
ggplot(iris) + geom_histogram(aes(x=Sepal.Length), stat="bin", binwidth = 3)
# Out:
# plot without title

# %%
ggplot(iris,aes(x=Species,y=Sepal.Length))+geom_bar(stat="identity")
# Out:
# plot without title

# %%
ggplot(iris) + geom_histogram(aes(x=Sepal.Length))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(iris,aes(x=Species,y=Sepal.Length,fill=Species))+geom_boxplot()
# Out:
# plot without title

# %%
 ggplot(data= iris, aes(x = Sepal.Length, y = Petal.Length)) +  geom_point(color = "darkred")
# Out:
# plot without title

# %%
install.packages("GGally", repos = "http://cran.us.r-project.org")
library(GGally)
# Out:
# also installing the dependencies 'prettyunits', 'progress', 'reshape'
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# GGally  1.3.0  1.3.1             FALSE
#
# package 'prettyunits' successfully unpacked and MD5 sums checked
# package 'progress' successfully unpacked and MD5 sums checked
# package 'reshape' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\kellyzhai\AppData\Local\Temp\RtmpolD6QP\downloaded_packages
# installing the source package 'GGally'

# %%
ggpairs(iris, aes(colour=Species), alpha=0.4)
# Out:
# Warning message in warn_if_args_exist(list(...)):
# "Extra arguments: "alpha" are being ignored.  If these are meant to be aesthetics, submit them using the 'mapping' variable within ggpairs with ggplot2::aes or ggplot2::aes_string."`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(iris, aes(x = "", y = Sepal.Length, fill = Species)) + geom_bar(stat = "identity") + coord_polar(theta = "y")
# Out:
# plot without title
